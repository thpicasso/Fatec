# %% [markdown]
# <a href="https://colab.research.google.com/github/thpicasso/Fatec/blob/main/ExemploEstadios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import json
import folium

# !python -m pip install pymongo
from pymongo import MongoClient
# Out:
# Collecting pymongo
#   Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 20.3 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 9.6 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.10.1

# %%
dataset = "https://raw.githubusercontent.com/ProfAndersonVanin/FATEC_BDNAORELACIONAL_2SEM2024/refs/heads/main/Coordenadas%20csv.csv"

# %%
estadios_df = pd.read_csv(dataset)

# %%
estadios_df.head(5)
# Out:
#              nome  capacidade  latitude  longitude
# 0        Maracanã       78838 -22.90981  -43.23391
# 1  Mané Garrincha       72000 -15.78375  -47.89903
# 2         Morumbi       66795 -23.60006  -46.72016
# 3  Arena Castelão       63903  -3.80674  -38.52168
# 4        Mineirão       61927 -19.86591  -43.97104

# %%
dicionario = estadios_df.to_dict('records')

# %%
dicionario
# Out:
# [{'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
cliente = MongoClient('mongodb+srv://thalesplalbino:1234@clusterestadio.7i25w.mongodb.net/?retryWrites=true&w=majority&appName=ClusterEstadio')

# %%
db = cliente.get_database('Futebol')

# %%
db.estadios.insert_many(dicionario)
# Out:
# InsertManyResult([ObjectId('6714595f290c5e2d464c76aa'), ObjectId('6714595f290c5e2d464c76ab'), ObjectId('6714595f290c5e2d464c76ac'), ObjectId('6714595f290c5e2d464c76ad'), ObjectId('6714595f290c5e2d464c76ae'), ObjectId('6714595f290c5e2d464c76af'), ObjectId('6714595f290c5e2d464c76b0'), ObjectId('6714595f290c5e2d464c76b1'), ObjectId('6714595f290c5e2d464c76b2'), ObjectId('6714595f290c5e2d464c76b3'), ObjectId('6714595f290c5e2d464c76b4'), ObjectId('6714595f290c5e2d464c76b5'), ObjectId('6714595f290c5e2d464c76b6'), ObjectId('6714595f290c5e2d464c76b7'), ObjectId('6714595f290c5e2d464c76b8'), ObjectId('6714595f290c5e2d464c76b9'), ObjectId('6714595f290c5e2d464c76ba'), ObjectId('6714595f290c5e2d464c76bb'), ObjectId('6714595f290c5e2d464c76bc'), ObjectId('6714595f290c5e2d464c76bd')], acknowledged=True)

# %%
estadios = db.estadios

# %%
list(estadios.find())
# Out:
# [{'_id': ObjectId('6714595f290c5e2d464c76aa'),
#   'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'_id': ObjectId('6714595f290c5e2d464c76ab'),
#   'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'_id': ObjectId('6714595f290c5e2d464c76ac'),
#   'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'_id': ObjectId('6714595f290c5e2d464c76ad'),
#   'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'_id': ObjectId('6714595f290c5e2d464c76ae'),
#   'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'_id': ObjectId('6714595f290c5e2d464c76af'),
#   'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('6714595f290c5e2d464c76b0'),
#   'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'_id': ObjectId('6714595f290c5e2d464c76b1'),
#   'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'_id': ObjectId('6714595f290c5e2d464c76b2'),
#   'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'_id': ObjectId('6714595f290c5e2d464c76b3'),
#   'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'_id': ObjectId('6714595f290c5e2d464c76b4'),
#   'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'_id': ObjectId('6714595f290c5e2d464c76b5'),
#   'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'_id': ObjectId('6714595f290c5e2d464c76b6'),
#   'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('6714595f290c5e2d464c76b7'),
#   'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'_id': ObjectId('6714595f290c5e2d464c76b8'),
#   'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'_id': ObjectId('6714595f290c5e2d464c76b9'),
#   'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'_id': ObjectId('6714595f290c5e2d464c76ba'),
#   'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'_id': ObjectId('6714595f290c5e2d464c76bb'),
#   'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'_id': ObjectId('6714595f290c5e2d464c76bc'),
#   'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'_id': ObjectId('6714595f290c5e2d464c76bd'),
#   'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
center_lat = -14.24007
center_lon = -53.18050

# %%
consulta = list(estadios.find())

# %%
df_convertido = pd.DataFrame(consulta)

# %%
df_convertido.iloc[0]
# Out:
# _id           6714595f290c5e2d464c76aa
# nome                          Maracanã
# capacidade                       78838
# latitude                     -22.90981
# longitude                    -43.23391
# Name: 0, dtype: object

# %%
locationmap = folium.Map(location=[center_lat, center_lon], zoom_start=4, width=800, height=600)

# %%
qtde = len(df_convertido)

# %%
qtde
# Out:
# 20

# %%
for i in range(qtde):
  lng = float(df_convertido.iloc[i]['longitude'])
  lat = float(df_convertido.iloc[i]['latitude'])
  description = 'Estadio: ' + str(df_convertido.iloc[i]['nome']) + '<br> Capacidade: ' + str(df_convertido.iloc[i]['capacidade'])
  folium.Marker([lat, lng],
                popup= description,
                icon=folium.Icon(color='red')).add_to(locationmap)

# %%
locationmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5428984f95c7a77a6deaa06b41313bd4 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5428984f95c7a77a6deaa06b41313bd4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5428984f95c7a77a6deaa06b41313bd4 = L.map(
#                 &quot;map_5428984f95c7a77a6deaa06b41313bd4&quot;,
#                 {
#                     center: [-14.24007, -53.1805],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d3b77ff8619983aef131d52877f35fb3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d3b77ff8619983aef131d52877f35fb3.addTo(map_5428984f95c7a77a6deaa06b41313bd4);
#
#
#             var marker_493480d7082d4537f0d7b288e05b1489 = L.marker(
#                 [-22.90981, -43.23391],
#                 {}
#             ).addTo(map_5428984f95c7a77a6deaa06b41313bd4);
#
#
#             var icon_71d07a3ec1ba56e0047d978868e3b98e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_493480d7082d4537f0d7b288e05b1489.setIcon(icon_71d07a3ec1ba56e0047d978868e3b98e);
#
#
#         var popup_f7f07852c2dee3b2d7fdd0a15a6927d5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_72a5459a8bb9a0d30b60f7bb8abe7b48 = $(`&lt;div id=&quot;html_72a5459a8bb9a0d30b60f7bb8abe7b48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estadio: Maracanã&lt;br&gt; Capacidade: 78838&lt;/div&gt;`)[0];
#                 popup_f7f07852c2dee3b2d7fdd0a15a6927d5.setContent(html_72a5459a8bb9a0d30b60f7bb8abe7b48);
#
#
#
#         marker_493480d7082d4537f0d7b288e05b1489.bindPopup(popup_f7f07852c2dee3b2d7fdd0a15a6927d5)
#         ;
#
#
#
#
#             var marker_d00ca4703a4c6e0e2f35e0a0a3f4f957 = L.marker(
#                 [-15.78375, -47.89903],
#                 {}
#             ).addTo(map_5428984f95c7a77a6deaa06b41313bd4);
#
#
#             var icon_66a2966e033a9bc88e43572a961ce585 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d00ca4703a4c6e0e2f35e0a0a3f4f957.setIcon(icon_66a2966e033a9bc88e43572a961ce585);
#
#
#         var popup_5eaa9a97f69318cae484fca1c5cb52a8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6869683327afdd16d0064797bcfab2c9 = $(`&lt;div id=&quot;html_6869683327afdd16d0064797bcfab2c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estadio: Mané Garrincha&lt;br&gt; Capacidade: 72000&lt;/div&gt;`)[0];
#                 popup_5eaa9a97f69318cae484fca1c5cb52a8.setContent(html_6869683327afdd16d0064797bcfab2c9);
#
#
#
#         marker_d00ca4703a4c6e0e2f35e0a0a3f4f957.bindPopup(popup_5eaa9a97f69318cae484fca1c5cb52a8)
#         ;
#
#
#
#
#             var marker_32b94400bae7ffbce87cf42d728003ac = L.marker(
#                 [-23.60006, -46.72016],
#                 {}
#             ).addTo(map_5428984f95c7a77a6deaa06b41313bd4);
#
#
#             var icon_0a3248802fe57e25a90c8fffbad03d97 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_32b94400bae7ffbce87cf42d728003ac.setIcon(icon_0a3248802fe57e25a90c8fffbad03d97);
#
#
#         var popup_ed59ac1066a10a766440540a6281b018 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6727e95f9a4950aba539dd51b6c7f25e = $(`&lt;div id=&quot;html_6727e95f9a4950aba539dd51b6c7f25e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estadio: Morumbi&lt;br&gt; Capacidade: 66795&lt;/div&gt;`)[0];
#                 popup_ed59ac1066a10a766440540a6281b018.setContent(html_6727e95f9a4950aba539dd51b6c7f25e);
#
#
#
#         marker_32b94400bae7ffbce87cf42d728003ac.bindPopup(popup_ed59ac1066a10a766440540a6281b018)
#         ;
#
#
#
#
#             var marker_42149a5b26515c0463e0aade144e8086 = L.marker(
#                 [-3.80674, -38.52168],
#                 {}
#             ).addTo(map_5428984f95c7a77a6deaa06b41313bd4);
#
#
#             var icon_c109f190d676930350951c22dfada8d0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate
